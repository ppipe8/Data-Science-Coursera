# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>
#
# # Simple APIs
# ## Random User and Fruitvice API Examples
#
#
# Estimated time needed: **25** minutes
#
# ## Objectives
#
# After completing this lab you will be able to:
#
# *   Load and use RandomUser API, using `RandomUser()` Python library
# *   Load and use Fruitvice API, using `requests` Python library

# %% [markdown]
# The purpose of this notebook is to provide more examples on how to use simple APIs. As you have already learned from previous videos and notebooks, API stands for Application Programming Interface and is a software intermediary that allows two applications to talk to each other.
#
# The advantages of using APIs:
#  *   **Automation**. Less human effort is required and workflows can be easily updated to become faster and more
#      productive.
#  *   **Efficiency**. It allows to use the capabilities of one of the already developed APIs than to try to
#      independently implement some functionality from scratch.
#
# The disadvantage of using APIs:
#  *   **Secirity**. If the API is poorly integrated, it means it will be vulnerable to attacks, resulting in data
#      breeches or losses having financial or reputation implications.
#
# One of the applications we will use in this notebook is Random User Generator. RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on [RandomUser](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01#intro) can be found here.
#
# Another example of simple API we will use in this notebook is Fruitvice application. The Fruitvice API webservice which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The webservice is completely free to use and contribute to.

# %% [markdown]
# ## Example 1: RandomUser API
# Bellow are Get Methods parameters that we can generate. For more information on the parameters, please visit this [documentation](https://randomuser.me/documentation?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) page.

# %% [markdown]
# ## **Get Methods**
#
# - get_cell()
# - get_city()
# - get_dob()
# - get_email()
# - get_first_name()
# - get_full_name()
# - get_gender()
# - get_id()
# - get_id_number()
# - get_id_type()
# - get_info()
# - get_last_name()
# - get_login_md5()
# - get_login_salt()
# - get_login_sha1()
# - get_login_sha256()
# - get_nat()
# - get_password()
# - get_phone()
# - get_picture()
# - get_postcode()
# - get_registered()
# - get_state()
# - get_street()
# - get_username()
# - get_zipcode()

# %% [markdown]
# To start using the API you can install the `randomuser` library running the `pip install` command.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (setup.py) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5067 sha256=0a948d384cce6bee30deb2d33243a588de17b17e39088a126294c5db5382331c
#   Stored in directory: /home/jupyterlab/.cache/pip/wheels/f8/a9/23/1df3ef7a5177d99b4cba8fa52415e1360bde68f520c2a0e489
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# Then, we will load the necessary libraries.

# %%
from randomuser import RandomUser
import pandas as pd

# %% [markdown]
# First, we will create a random user object, r.

# %%
r = RandomUser()

# %% [markdown]
# Then, using `generate_users()` function, we get a list of random 10 users.

# %%
some_list = r.generate_users(10)

# %%
some_list
# Out:
# [<randomuser.RandomUser at 0x7f21a5a6fed0>,
#  <randomuser.RandomUser at 0x7f21a5a6ff10>,
#  <randomuser.RandomUser at 0x7f21a5a6ff50>,
#  <randomuser.RandomUser at 0x7f21a5a6ff90>,
#  <randomuser.RandomUser at 0x7f21a5a6ffd0>,
#  <randomuser.RandomUser at 0x7f21a5a74090>,
#  <randomuser.RandomUser at 0x7f21a5a740d0>,
#  <randomuser.RandomUser at 0x7f21a5a74110>,
#  <randomuser.RandomUser at 0x7f21a5a74150>,
#  <randomuser.RandomUser at 0x7f21a5a74050>]

# %% [markdown]
# The **"Get Methods"** functions mentioned at the beginning of this notebook, can generate the required parameters to construct a dataset. For example, to get full name, we call `get_full_name()` function.

# %%
name = r.get_full_name()

# %% [markdown]
# Let's say we only need 10 users with full names and their email addresses. We can write a "for-loop" to print these 10 users.

# %%
for user in some_list:
    print (user.get_full_name()," ",user.get_email())
# Out:
# Jeremy Slawa   jeremy.slawa@example.com
# Isabella Andersen   isabella.andersen@example.com
# Harrison Morris   harrison.morris@example.com
# Alma Rolland   alma.rolland@example.com
# Julia Macdonald   julia.macdonald@example.com
# Anine Harestad   anine.harestad@example.com
# Murat Aydan   murat.aydan@example.com
# Eleanor Smith   eleanor.smith@example.com
# Misael Ramos   misael.ramos@example.com
# Holly Porter   holly.porter@example.com

# %% [markdown]
# ## Exercise 1
# In this Exercise, generate photos of the random 5 users.

# %%
## Write your code here
r = RandomUser()
some_list = r.generate_users(5)

for user in some_list:
    print(user.get_full_name(),' ',user.get_picture())
# Out:
# Pearl Murphy   https://randomuser.me/api/portraits/women/87.jpg
# Elliot Austin   https://randomuser.me/api/portraits/men/37.jpg
# یسنا حسینی   https://randomuser.me/api/portraits/women/83.jpg
# Delphine Fortin   https://randomuser.me/api/portraits/women/82.jpg
# Miguel Suarez   https://randomuser.me/api/portraits/men/24.jpg

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# for user in some_list:
#     print (user.get_picture())
# ```
#
# </details>

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users =[]
     
    for user in RandomUser.generate_users(10):
        users.append({"Name":user.get_full_name(),"Gender":user.get_gender(),"City":user.get_city(),"State":user.get_state(),"Email":user.get_email(), "DOB":user.get_dob(),"Picture":user.get_picture()})
    print(users)
    return pd.DataFrame(users)

# %%
get_users()
# Out:
# [{'Name': 'Mendy De Klerk', 'Gender': 'female', 'City': 'Gennep', 'State': 'Overijssel', 'Email': 'mendy.deklerk@example.com', 'DOB': '1958-06-22T21:04:09.145Z', 'Picture': 'https://randomuser.me/api/portraits/women/57.jpg'}, {'Name': 'Oscar Hunter', 'Gender': 'male', 'City': 'Salford', 'State': 'Tayside', 'Email': 'oscar.hunter@example.com', 'DOB': '1979-03-23T17:12:17.610Z', 'Picture': 'https://randomuser.me/api/portraits/men/49.jpg'}, {'Name': 'Eelis Kivisto', 'Gender': 'male', 'City': 'Muonio', 'State': 'Southern Ostrobothnia', 'Email': 'eelis.kivisto@example.com', 'DOB': '1971-10-22T10:45:19.234Z', 'Picture': 'https://randomuser.me/api/portraits/men/98.jpg'}, {'Name': 'Antonio Soto', 'Gender': 'male', 'City': 'Fuenlabrada', 'State': 'Galicia', 'Email': 'antonio.soto@example.com', 'DOB': '1955-12-20T15:07:16.741Z', 'Picture': 'https://randomuser.me/api/portraits/men/19.jpg'}, {'Name': 'Ladina Clement', 'Gender': 'female', 'City': 'Birrhard', 'State': 'Neuchâtel', 'Email': 'ladina.clement@example.com', 'DOB': '1988-04-23T07:30:30.927Z', 'Picture': 'https://randomuser.me/api/portraits/women/83.jpg'}, {'Name': 'Filinto Silveira', 'Gender': 'male', 'City': 'Colatina', 'State': 'Paraíba', 'Email': 'filinto.silveira@example.com', 'DOB': '1976-05-14T03:27:52.657Z', 'Picture': 'https://randomuser.me/api/portraits/men/64.jpg'}, {'Name': 'Harold Andrews', 'Gender': 'male', 'City': 'Hervey Bay', 'State': 'Victoria', 'Email': 'harold.andrews@example.com', 'DOB': '1963-08-25T09:48:47.456Z', 'Picture': 'https://randomuser.me/api/portraits/men/55.jpg'}, {'Name': 'Richard Gerard', 'Gender': 'male', 'City': 'Wolfenschiessen', 'State': 'Genève', 'Email': 'richard.gerard@example.com', 'DOB': '1962-12-14T12:51:44.541Z', 'Picture': 'https://randomuser.me/api/portraits/men/41.jpg'}, {'Name': 'Kübra Topçuoğlu', 'Gender': 'female', 'City': 'Kütahya', 'State': 'Hatay', 'Email': 'kubra.topcuoglu@example.com', 'DOB': '1993-08-02T21:12:34.726Z', 'Picture': 'https://randomuser.me/api/portraits/women/62.jpg'}, {'Name': 'Aléxio da Luz', 'Gender': 'male', 'City': 'Santa Maria', 'State': 'Sergipe', 'Email': 'alexio.daluz@example.com', 'DOB': '1967-11-20T09:53:19.604Z', 'Picture': 'https://randomuser.me/api/portraits/men/71.jpg'}]
#                Name  Gender             City                  State  \
# 0    Mendy De Klerk  female           Gennep             Overijssel
# 1      Oscar Hunter    male          Salford                Tayside
# 2     Eelis Kivisto    male           Muonio  Southern Ostrobothnia
# 3      Antonio Soto    male      Fuenlabrada                Galicia
# 4    Ladina Clement  female         Birrhard              Neuchâtel
# 5  Filinto Silveira    male         Colatina                Paraíba
# 6    Harold Andrews    male       Hervey Bay               Victoria
# 7    Richard Gerard    male  Wolfenschiessen                 Genève
# 8   Kübra Topçuoğlu  female          Kütahya                  Hatay
# 9     Aléxio da Luz    male      Santa Maria                Sergipe
#
#                           Email                       DOB  \
# 0     mendy.deklerk@example.com  1958-06-22T21:04:09.145Z
# 1      oscar.hunter@example.com  1979-03-23T17:12:17.610Z
# 2     eelis.kivisto@example.com  1971-10-22T10:45:19.234Z
# 3      antonio.soto@example.com  1955-12-20T15:07:16.741Z
# 4    ladina.clement@example.com  1988-04-23T07:30:30.927Z
# 5  filinto.silveira@example.com  1976-05-14T03:27:52.657Z
# 6    harold.andrews@example.com  1963-08-25T09:48:47.456Z
# 7    richard.gerard@example.com  1962-12-14T12:51:44.541Z
# 8   kubra.topcuoglu@example.com  1993-08-02T21:12:34.726Z
# 9      alexio.daluz@example.com  1967-11-20T09:53:19.604Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/57.jpg
# 1    https://randomuser.me/api/portraits/men/49.jpg
# 2    https://randomuser.me/api/portraits/men/98.jpg
# 3    https://randomuser.me/api/portraits/men/19.jpg
# 4  https://randomuser.me/api/portraits/women/83.jpg
# 5    https://randomuser.me/api/portraits/men/64.jpg
# 6    https://randomuser.me/api/portraits/men/55.jpg
# 7    https://randomuser.me/api/portraits/men/41.jpg
# 8  https://randomuser.me/api/portraits/women/62.jpg
# 9    https://randomuser.me/api/portraits/men/71.jpg

# %%
df1 = pd.DataFrame(get_users())
# Out:
# [{'Name': 'Nikolaj Jørgensen', 'Gender': 'male', 'City': 'Sommersted', 'State': 'Danmark', 'Email': 'nikolaj.jorgensen@example.com', 'DOB': '1968-05-18T17:37:29.596Z', 'Picture': 'https://randomuser.me/api/portraits/men/48.jpg'}, {'Name': 'Constance Silva', 'Gender': 'female', 'City': 'Dubbo', 'State': 'Northern Territory', 'Email': 'constance.silva@example.com', 'DOB': '1953-11-13T12:13:46.468Z', 'Picture': 'https://randomuser.me/api/portraits/women/42.jpg'}, {'Name': 'Lara Gaillard', 'Gender': 'female', 'City': 'Dürrenroth', 'State': 'Obwalden', 'Email': 'lara.gaillard@example.com', 'DOB': '1986-10-11T17:00:54.960Z', 'Picture': 'https://randomuser.me/api/portraits/women/17.jpg'}, {'Name': 'Emil Toivonen', 'Gender': 'male', 'City': 'Pihtipudas', 'State': 'Åland', 'Email': 'emil.toivonen@example.com', 'DOB': '1960-06-21T14:41:26.887Z', 'Picture': 'https://randomuser.me/api/portraits/men/83.jpg'}, {'Name': 'Oneide Monteiro', 'Gender': 'female', 'City': 'Paranaguá', 'State': 'Piauí', 'Email': 'oneide.monteiro@example.com', 'DOB': '1962-11-18T01:59:00.270Z', 'Picture': 'https://randomuser.me/api/portraits/women/76.jpg'}, {'Name': 'Hugo Harris', 'Gender': 'male', 'City': 'Gisborne', 'State': 'Northland', 'Email': 'hugo.harris@example.com', 'DOB': '1989-06-15T19:54:27.513Z', 'Picture': 'https://randomuser.me/api/portraits/men/46.jpg'}, {'Name': 'Florian Renaud', 'Gender': 'male', 'City': 'Eggenwil', 'State': 'Genève', 'Email': 'florian.renaud@example.com', 'DOB': '1993-12-07T06:34:18.845Z', 'Picture': 'https://randomuser.me/api/portraits/men/64.jpg'}, {'Name': 'Clair Dias', 'Gender': 'female', 'City': 'Canoas', 'State': 'Amazonas', 'Email': 'clair.dias@example.com', 'DOB': '1948-08-15T15:30:27.061Z', 'Picture': 'https://randomuser.me/api/portraits/women/19.jpg'}, {'Name': 'Ceyhan Atan', 'Gender': 'female', 'City': 'Niğde', 'State': 'Niğde', 'Email': 'ceyhan.atan@example.com', 'DOB': '1956-12-23T21:41:20.338Z', 'Picture': 'https://randomuser.me/api/portraits/women/75.jpg'}, {'Name': 'Sevinç Elmi', 'Gender': 'female', 'City': 'Kapellebrug', 'State': 'Zuid-Holland', 'Email': 'sevinc.elmi@example.com', 'DOB': '1966-11-11T01:36:19.908Z', 'Picture': 'https://randomuser.me/api/portraits/women/88.jpg'}]

# %% [markdown]
# Now we have a *pandas* dataframe that can be used for any testing purposes that the tester might have.

# %% [markdown]
# ## Example 2: Fruitvice API
#
# Another, more common way to use APIs, is through `requests` library. The next lab, Requests and HTTP, will contain more information about requests.
#
# We will start by importing all required libraries.

# %%
import requests
import json

# %% [markdown]
# We will obtain the [fruitvice](https://www.fruityvice.com/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDeveloperSkillsNetworkPY0101ENSkillsNetwork1005-2022-01-01) API data using `requests.get("url")` function. The data is in a json format.

# %%
data = requests.get("https://fruityvice.com/api/fruit/all")

# %% [markdown]
# We will retrieve results using `json.loads()` function.

# %%
results = json.loads(data.text)

# %% [markdown]
# We will convert our json data into *pandas* data frame.

# %%
pd.DataFrame(results)
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#                                            nutritions
# 0   {'carbohydrates': 11.4, 'protein': 0.3, 'fat':...
# 1   {'carbohydrates': 3.9, 'protein': 0.5, 'fat': ...
# 2   {'carbohydrates': 8.53, 'protein': 2, 'fat': 1...
# 3   {'carbohydrates': 22, 'protein': 1, 'fat': 0.2...
# 4   {'carbohydrates': 9, 'protein': 1.3, 'fat': 0....
# 5   {'carbohydrates': 5.5, 'protein': 0, 'fat': 0....
# 6   {'carbohydrates': 12, 'protein': 1, 'fat': 0.3...
# 7   {'carbohydrates': 12.2, 'protein': 0.4, 'fat':...
# 8   {'carbohydrates': 9, 'protein': 9, 'fat': 1.5,...
# 9   {'carbohydrates': 27.1, 'protein': 1.5, 'fat':...
# 10  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....
# 11  {'carbohydrates': 19, 'protein': 0.8, 'fat': 0...
# 12  {'carbohydrates': 10, 'protein': 0.9, 'fat': 0...
# 13  {'carbohydrates': 18.1, 'protein': 0.72, 'fat'...
# 14  {'carbohydrates': 3.1, 'protein': 0.4, 'fat': ...
# 15  {'carbohydrates': 14, 'protein': 2.6, 'fat': 1...
# 16  {'carbohydrates': 15, 'protein': 1.1, 'fat': 0...
# 17  {'carbohydrates': 14.6, 'protein': 1.14, 'fat'...
# 18  {'carbohydrates': 9, 'protein': 1.1, 'fat': 0....
# 19  {'carbohydrates': 8.4, 'protein': 0.3, 'fat': ...
# 20  {'carbohydrates': 11.3, 'protein': 0.75, 'fat'...
# 21  {'carbohydrates': 17, 'protein': 0.8, 'fat': 0...
# 22  {'carbohydrates': 15, 'protein': 0.82, 'fat': ...
# 23  {'carbohydrates': 8, 'protein': 0, 'fat': 0, '...
# 24  {'carbohydrates': 9.8, 'protein': 1.44, 'fat':...
# 25  {'carbohydrates': 8.3, 'protein': 1, 'fat': 0....
# 26  {'carbohydrates': 11, 'protein': 0, 'fat': 0.4...
# 27  {'carbohydrates': 22.4, 'protein': 2.2, 'fat':...
# 28  {'carbohydrates': 9.5, 'protein': 0.9, 'fat': ...
# 29  {'carbohydrates': 15, 'protein': 0.4, 'fat': 0...
# 30  {'carbohydrates': 18, 'protein': 0, 'fat': 0, ...
# 31  {'carbohydrates': 13.12, 'protein': 0.54, 'fat...
# 32  {'carbohydrates': 7, 'protein': 1, 'fat': 0.4,...
# 33  {'carbohydrates': 11.4, 'protein': 0.7, 'fat':...
# 34  {'carbohydrates': 18.7, 'protein': 1.7, 'fat':...
# 35  {'carbohydrates': 12, 'protein': 1.2, 'fat': 0...
# 36  {'carbohydrates': 5.5, 'protein': 0.8, 'fat': ...
# 37  {'carbohydrates': 8.3, 'protein': 0, 'fat': 0....
# 38  {'carbohydrates': 3.9, 'protein': 0.9, 'fat': ...
# 39  {'carbohydrates': 8, 'protein': 0.6, 'fat': 0....

# %% [markdown]
# The result is in a nested json format. The 'nutrition' column contains multiple subcolumns, so the data needs to be 'flattened' or normalized.

# %%
df2 = pd.json_normalize(results)

# %%
df2
# Out:
#            genus          name  id           family             order  \
# 0          Malus         Apple   6         Rosaceae           Rosales
# 1         Prunus       Apricot  35         Rosaceae           Rosales
# 2         Persea       Avocado  84        Lauraceae          Laurales
# 3           Musa        Banana   1         Musaceae      Zingiberales
# 4          Rubus    Blackberry  64         Rosaceae           Rosales
# 5       Fragaria     Blueberry  33         Rosaceae           Rosales
# 6         Prunus        Cherry   9         Rosaceae           Rosales
# 7      Vaccinium     Cranberry  87        Ericaceae          Ericales
# 8   Selenicereus   Dragonfruit  80        Cactaceae    Caryophyllales
# 9          Durio        Durian  60        Malvaceae          Malvales
# 10    Sellowiana        Feijoa  76        Myrtaceae        Myrtoideae
# 11         Ficus           Fig  68         Moraceae           Rosales
# 12         Ribes    Gooseberry  69  Grossulariaceae      Saxifragales
# 13         Vitis         Grape  81         Vitaceae           Vitales
# 14         Malus    GreenApple  72         Rosaceae           Rosales
# 15       Psidium         Guava  37        Myrtaceae          Myrtales
# 16       Apteryx          Kiwi  66    Actinidiaceae  Struthioniformes
# 17     Actinidia     Kiwifruit  85    Actinidiaceae          Ericales
# 18        Citrus         Lemon  26         Rutaceae        Sapindales
# 19        Citrus          Lime  44         Rutaceae        Sapindales
# 20     Vaccinium   Lingonberry  65        Ericaceae          Ericales
# 21        Litchi        Lychee  67      Sapindaceae        Sapindales
# 22     Mangifera         Mango  27    Anacardiaceae        Sapindales
# 23       Cucumis         Melon  41    Cucurbitaceae     Cucurbitaceae
# 24         Morus         Morus  82         Moraceae           Rosales
# 25        Citrus        Orange   2         Rutaceae        Sapindales
# 26        Carica        Papaya  42       Caricaceae         Caricacea
# 27    Passiflora  Passionfruit  70   Passifloraceae      Malpighiales
# 28        Prunus         Peach  86         Rosaceae           Rosales
# 29         Pyrus          Pear   4         Rosaceae           Rosales
# 30     Diospyros     Persimmon  52        Ebenaceae           Rosales
# 31        Ananas     Pineapple  10     Bromeliaceae            Poales
# 32     Cactaceae      Pitahaya  78        Cactaceae    Caryophyllales
# 33        Prunus          Plum  71         Rosaceae           Rosales
# 34        Punica   Pomegranate  79       Lythraceae          Myrtales
# 35         Rubus     Raspberry  23         Rosaceae           Rosales
# 36      Fragaria    Strawberry   3         Rosaceae           Rosales
# 37        Citrus     Tangerine  77         Rutaceae        Sapindales
# 38       Solanum        Tomato   5       Solanaceae         Solanales
# 39     Citrullus    Watermelon  25    Cucurbitaceae      Cucurbitales
#
#     nutritions.carbohydrates  nutritions.protein  nutritions.fat  \
# 0                      11.40                0.30            0.40
# 1                       3.90                0.50            0.10
# 2                       8.53                2.00           14.66
# 3                      22.00                1.00            0.20
# 4                       9.00                1.30            0.40
# 5                       5.50                0.00            0.40
# 6                      12.00                1.00            0.30
# 7                      12.20                0.40            0.10
# 8                       9.00                9.00            1.50
# 9                      27.10                1.50            5.30
# 10                      8.00                0.60            0.40
# 11                     19.00                0.80            0.30
# 12                     10.00                0.90            0.60
# 13                     18.10                0.72            0.16
# 14                      3.10                0.40            0.10
# 15                     14.00                2.60            1.00
# 16                     15.00                1.10            0.50
# 17                     14.60                1.14            0.50
# 18                      9.00                1.10            0.30
# 19                      8.40                0.30            0.10
# 20                     11.30                0.75            0.34
# 21                     17.00                0.80            0.44
# 22                     15.00                0.82            0.38
# 23                      8.00                0.00            0.00
# 24                      9.80                1.44            0.39
# 25                      8.30                1.00            0.20
# 26                     11.00                0.00            0.40
# 27                     22.40                2.20            0.70
# 28                      9.50                0.90            0.25
# 29                     15.00                0.40            0.10
# 30                     18.00                0.00            0.00
# 31                     13.12                0.54            0.12
# 32                      7.00                1.00            0.40
# 33                     11.40                0.70            0.28
# 34                     18.70                1.70            1.20
# 35                     12.00                1.20            0.70
# 36                      5.50                0.80            0.40
# 37                      8.30                0.00            0.40
# 38                      3.90                0.90            0.20
# 39                      8.00                0.60            0.20
#
#     nutritions.calories  nutritions.sugar
# 0                    52             10.30
# 1                    15              3.20
# 2                   160              0.66
# 3                    96             17.20
# 4                    40              4.50
# 5                    29              5.40
# 6                    50              8.00
# 7                    46              4.00
# 8                    60              8.00
# 9                   147              6.75
# 10                   44              3.00
# 11                   74             16.00
# 12                   44              0.00
# 13                   69             16.00
# 14                   21              6.40
# 15                   68              9.00
# 16                   61              9.00
# 17                   61              8.90
# 18                   29              2.50
# 19                   25              1.70
# 20                   50              5.74
# 21                   66             15.00
# 22                   60             13.70
# 23                   34              8.00
# 24                   43              8.10
# 25                   43              8.20
# 26                   43              1.00
# 27                   97             11.20
# 28                   39              8.40
# 29                   57             10.00
# 30                   81             18.00
# 31                   50              9.85
# 32                   36              3.00
# 33                   46              9.92
# 34                   83             13.70
# 35                   53              4.40
# 36                   29              5.40
# 37                   45              9.10
# 38                   74              2.60
# 39                   30              6.00

# %% [markdown]
# Let's see if we can extract some information from this dataframe. Perhaps, we need to know the family and genus of a cherry.

# %%
cherry = df2.loc[df2["name"] == 'Cherry']
(cherry.iloc[0]['family']) , (cherry.iloc[0]['genus'])
# Out:
# ('Rosaceae', 'Prunus')

# %% [markdown]
# ## Exercise 2
# In this Exercise, find out how many calories are contained in a banana.

# %%
# Write your code here
banana = df2.loc[df2['name'] == 'Banana']
print('calories =',banana.iloc[0]['nutritions.calories'])
# Out:
# calories = 96

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# cal_banana = df2.loc[df2["name"] == 'Banana']
# cal_banana.iloc[0]['nutritions.calories']
# ```
#
# </details>

# %% [markdown]
# ## Exercise 3
#
# This [page](https://github.com/public-apis/public-apis#animals) contains a list of free public APIs. Choose any API of your interest and use it to load/extract some information, as shown in the example above.
# 1. Using `requests.get("url")` function, load your data.

# %%
# Write your code here
import requests
import json

url = 'https://itunes.apple.com/search?'
keysvals = {'term':'lord huron','country':'us','limit':5}

r = requests.get(url,params = keysvals)
r
# Out:
# <Response [200]>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# data2 = requests.get("https://www.fishwatch.gov/api/species")
# ```
#
# </details>

# %% [markdown]
# 2. Retrieve results using `json.loads()` function.

# %%
# Write your code here
results = json.loads(r.text)
results
# Out:
# {'resultCount': 5,
#  'results': [{'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 393068687,
#    'collectionId': 962688212,
#    'trackId': 962688837,
#    'artistName': 'Lord Huron',
#    'collectionName': 'Strange Trails',
#    'trackName': 'The Night We Met',
#    'collectionCensoredName': 'Strange Trails',
#    'trackCensoredName': 'The Night We Met',
#    'artistViewUrl': 'https://music.apple.com/us/artist/lord-huron/393068687?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/the-night-we-met/962688212?i=962688837&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/the-night-we-met/962688212?i=962688837&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview115/v4/31/1f/92/311f9256-eea4-332f-60b8-1175a5e51151/mzaf_10603254290419235531.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2015-02-09T12:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 14,
#    'trackTimeMillis': 208212,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Indie Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 393068687,
#    'collectionId': 962688212,
#    'trackId': 962688824,
#    'artistName': 'Lord Huron',
#    'collectionName': 'Strange Trails',
#    'trackName': 'Fool for Love',
#    'collectionCensoredName': 'Strange Trails',
#    'trackCensoredName': 'Fool for Love',
#    'artistViewUrl': 'https://music.apple.com/us/artist/lord-huron/393068687?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/fool-for-love/962688212?i=962688824&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/fool-for-love/962688212?i=962688824&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/73/62/e1/7362e193-3185-48b5-3f96-39cbdbba42a8/mzaf_17112070138695412267.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 0.69,
#    'releaseDate': '2015-02-09T08:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 6,
#    'trackTimeMillis': 274705,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Indie Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 393068687,
#    'collectionId': 962688212,
#    'trackId': 962688826,
#    'artistName': 'Lord Huron',
#    'collectionName': 'Strange Trails',
#    'trackName': 'Meet Me in the Woods',
#    'collectionCensoredName': 'Strange Trails',
#    'trackCensoredName': 'Meet Me in the Woods',
#    'artistViewUrl': 'https://music.apple.com/us/artist/lord-huron/393068687?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/meet-me-in-the-woods/962688212?i=962688826&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/meet-me-in-the-woods/962688212?i=962688826&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/f7/e8/26/f7e826db-b766-5867-c565-b2e6c3fccbdc/mzaf_3252711097416884667.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 0.69,
#    'releaseDate': '2015-04-07T12:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'explicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 8,
#    'trackTimeMillis': 262209,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Indie Rock',
#    'contentAdvisoryRating': 'Explicit',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 393068687,
#    'collectionId': 962688212,
#    'trackId': 962688815,
#    'artistName': 'Lord Huron',
#    'collectionName': 'Strange Trails',
#    'trackName': 'Love Like Ghosts',
#    'collectionCensoredName': 'Strange Trails',
#    'trackCensoredName': 'Love Like Ghosts',
#    'artistViewUrl': 'https://music.apple.com/us/artist/lord-huron/393068687?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/love-like-ghosts/962688212?i=962688815&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/love-like-ghosts/962688212?i=962688815&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/5b/51/48/5b514856-45dd-f6bd-3798-dfcc81eee4db/mzaf_2434367525684044418.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2015-04-07T07:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 1,
#    'trackTimeMillis': 224062,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Indie Rock',
#    'isStreamable': True},
#   {'wrapperType': 'track',
#    'kind': 'song',
#    'artistId': 393068687,
#    'collectionId': 962688212,
#    'trackId': 962688825,
#    'artistName': 'Lord Huron',
#    'collectionName': 'Strange Trails',
#    'trackName': 'The World Ender',
#    'collectionCensoredName': 'Strange Trails',
#    'trackCensoredName': 'The World Ender',
#    'artistViewUrl': 'https://music.apple.com/us/artist/lord-huron/393068687?uo=4',
#    'collectionViewUrl': 'https://music.apple.com/us/album/the-world-ender/962688212?i=962688825&uo=4',
#    'trackViewUrl': 'https://music.apple.com/us/album/the-world-ender/962688212?i=962688825&uo=4',
#    'previewUrl': 'https://audio-ssl.itunes.apple.com/itunes-assets/AudioPreview125/v4/b2/f4/ef/b2f4ef4a-913c-4a23-ee07-27ea84c7eb8e/mzaf_12733828692439709380.plus.aac.p.m4a',
#    'artworkUrl30': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/30x30bb.jpg',
#    'artworkUrl60': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/60x60bb.jpg',
#    'artworkUrl100': 'https://is5-ssl.mzstatic.com/image/thumb/Music115/v4/29/eb/4d/29eb4db0-4e4f-06d1-5b37-cf7dcac0998d/886445056839.jpg/100x100bb.jpg',
#    'collectionPrice': 5.99,
#    'trackPrice': 1.29,
#    'releaseDate': '2015-03-10T12:00:00Z',
#    'collectionExplicitness': 'explicit',
#    'trackExplicitness': 'notExplicit',
#    'discCount': 1,
#    'discNumber': 1,
#    'trackCount': 13,
#    'trackNumber': 7,
#    'trackTimeMillis': 270054,
#    'country': 'USA',
#    'currency': 'USD',
#    'primaryGenreName': 'Indie Rock',
#    'isStreamable': True}]}

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# results2 = json.loads(data2.text)
# ```
#
# </details>

# %% [markdown]
# 3. Convert json data into *pandas* data frame.

# %%
# Write your code here
my_df = pd.json_normalize(results)
my_df
# Out:
#    resultCount                                            results
# 0           50  [{'wrapperType': 'track', 'kind': 'song', 'art...

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```python
# df3 = pd.DataFrame(results2)
# df3
# ```
#
# </details>

# %% [markdown]
# # Congratulations! - You have completed the lab

# %% [markdown]
# ## Author
# [Svitlana Kramar](www.linkedin.com/in/svitlana-kramar)
#
#
# Svitlana is a master’s degree Data Science and Analytics student at University of Calgary, who enjoys travelling, learning new languages and cultures and loves spreading her passion for Data Science.

# %% [markdown]
#                                 Copyright © 2020 IBM Corporation. All rights reserved.
